# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.52.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)

# %%
import openai
import json
import re
from typing import List, Dict
from google.colab import userdata

# Set your API key (input this manually)
key = userdata.get('OPENAI_API_KEY')
openai.api_key = key

schema_english = {
    "general information": {
        "name": "string",
        "brand": "string",
        "category": "string",
        "original_price": "float",
        "discount_price": "float",
        "description": "string",
        "design": "string",
        "promotion": "string",
    },
    "technical specifications": {
        "display": ["string"],
        "memory and storage": ["string"],
        "camera": "string",
        "battery": "string",
        "operating system": "string",
        "chip": "string",
        "connectivity": ["string"],
        "audio": "string",
        "charging and expansion": ["string"],
    },
    "extra_metadata": {
        "special feature": ["string"],
        "accessories": ["string"],
    }
}


def extract_and_clean_json_from_response(content: str) -> str:
    """Extract JSON data from a response and remove comments."""
    # Extract JSON content between ```json and ```
    json_match = re.search(r'```json\n(.*?)\n```', content, re.DOTALL)
    if json_match:
        json_content = json_match.group(1)

        # Remove any comments or lines with `//`
        cleaned_json_content = re.sub(r'//.*', '', json_content)
        return cleaned_json_content
    return None


def convert_to_json(raw_data, schema):
    # Define the prompt
    raw_data = raw_data.strip().rstrip('.').rstrip('...').strip()
    prompt = f"Convert the following raw data into JSON format based on this schema:\n\nSchema: {json.dumps(schema)}\n\nRaw Data: {json.dumps(raw_data)}"

    # Call the OpenAI API
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful assistant that formats data."},
            {"role": "user", "content": prompt}
        ],
        temperature=0,
    )

    # Extract and parse the JSON content
    content = response.choices[0].message.content.strip()
    json_content = extract_and_clean_json_from_response(content)

    if json_content:
        try:
            json_data = json.loads(json_content)  # Parse the JSON-formatted text
            return json_data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("No JSON found in response.")
    return None

def process_and_save_data(raw_data_list, output_file):
    schema = schema_english

    processed_data = []

    for raw_data in raw_data_list:
        json_data = convert_to_json(raw_data, schema)
        if json_data:
            processed_data.append(json_data)

    # Save the processed data to a JSON file
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(processed_data, f, ensure_ascii=False, indent=4)

# # Example usage with a list of raw data strings
# raw_data_list = [
#     "Tên sản phẩm: iPhone 13, Thương hiệu: Apple, Giá: 20000000, Danh mục: điện thoại thông minh",
#     "Tên sản phẩm: Galaxy S21, Thương hiệu: Samsung, Giá: 18000000, Danh mục: điện thoại thông minh",
#     "Tên sản phẩm: Xiaomi Mi 11, Thương hiệu: Xiaomi, Giá: 15000000, Danh mục: điện thoại thông minh",
#     "Tên sản phẩm: Oppo Find X3 Pro, Thương hiệu: Oppo, Giá: 22000000, Danh mục: điện thoại thông minh"
# ]

# # Save converted data to 'output_data.json'
# process_and_save_data(raw_data_list, 'output_data.json')

# %%
# import json

# # Open and read the JSON file
# with open('output_data.json', 'r') as file:
#     data = json.load(file)

# # Print the data
# print(data)
# Out:
# [{'general information': {'name': 'iPhone 13', 'brand': 'Apple', 'category': 'điện thoại thông minh', 'price': 20000000.0, 'description': '', 'design': ''}, 'technical specifications': {'display': [], 'memory and storage': [], 'camera': '', 'battery': '', 'operating system': '', 'chip': '', 'connectivity': [], 'audio': '', 'charging and expansion': []}, 'extra_metadata': {'special feature': [], 'accessories': []}}, {'general information': {'name': 'Galaxy S21', 'brand': 'Samsung', 'category': 'điện thoại thông minh', 'price': 18000000.0, 'description': '', 'design': ''}, 'technical specifications': {'display': [], 'memory and storage': [], 'camera': '', 'battery': '', 'operating system': '', 'chip': '', 'connectivity': [], 'audio': '', 'charging and expansion': []}, 'extra_metadata': {'special feature': [], 'accessories': []}}, {'general information': {'name': 'Xiaomi Mi 11', 'brand': 'Xiaomi', 'category': 'điện thoại thông minh', 'price': 15000000.0, 'description': '', 'design': ''}, 'technical specifications': {'display': [], 'memory and storage': [], 'camera': '', 'battery': '', 'operating system': '', 'chip': '', 'connectivity': [], 'audio': '', 'charging and expansion': []}, 'extra_metadata': {'special feature': [], 'accessories': []}}, {'general information': {'name': 'Oppo Find X3 Pro', 'brand': 'Oppo', 'category': 'điện thoại thông minh', 'price': 22000000.0, 'description': '', 'design': ''}, 'technical specifications': {'display': [], 'memory and storage': [], 'camera': '', 'battery': '', 'operating system': '', 'chip': '', 'connectivity': [], 'audio': '', 'charging and expansion': []}, 'extra_metadata': {'special feature': [], 'accessories': []}}]

# %% [markdown]
# # Raw Data:

# %%
import requests
from bs4 import BeautifulSoup

def spider(max_pages):
    page = 1
    while page <= max_pages:
        url = 'https://hoanghamobile.com/dien-thoai-di-dong?p=' + str(page)
        source_code = requests.get(url)
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text, 'html.parser')

        print("Products List:")
        print("================================================")
        # Tìm tất cả các thẻ <div> có class "pinfo" và trong đó có thẻ <h3>
        for pinfo in soup.find_all('div', class_='v5-item'):
            # Lấy thẻ <a> trong thẻ <h3> để lấy link
            link_tag = pinfo.find('h3').find('a')
            price_tag = pinfo.find('div', class_='price')
            href = 'https://hoanghamobile.com/' + link_tag.get('href')
            title = link_tag.get('title')
            print(f"Product Title: {title}")
            print(f"Product URL: {href}")
            print()

        page += 1

# Chạy hàm để kiểm tra
spider(1)  # Bạn có thể thay đổi số trang nếu muốn lấy nhiều hơn
# Out:
# Products List:
# ================================================
# Product Title: Samsung Galaxy Z Fold6 12GB/256GB
# Product URL: https://hoanghamobile.com//dien-thoai/samsung-galaxy-z-fold6
#
# Product Title: Samsung Galaxy Z Fold6 12GB/512GB
# Product URL: https://hoanghamobile.com//dien-thoai/samsung-galaxy-z-fold6-12gb-512gb
#
# Product Title: Samsung Galaxy Z Fold6 12GB/1TB
# Product URL: https://hoanghamobile.com//dien-thoai/samsung-galaxy-z-fold6-12gb-1tb
#
# Product Title: Samsung Galaxy Z Flip6 12GB/256GB
# Product URL: https://hoanghamobile.com//dien-thoai/samsung-galaxy-z-flip6
#
# Product Title: Samsung Galaxy Z Flip6 12GB/512GB
# Product URL: https://hoanghamobile.com//dien-thoai/samsung-galaxy-z-flip6-12gb-512gb
#
# Product Title: iPhone 16 Pro Max - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-pro-max
#
# Product Title: iPhone 16 - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16
#
# Product Title: iPhone 16 Pro - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-pro
#
# Product Title: iPhone 16 Plus - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-plus
#
# Product Title: iPhone 16 Pro Max (512GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-pro-max-512gb
#
# Product Title: iPhone 16 (256GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-256gb
#
# Product Title: iPhone 16 Pro (256GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-pro-256gb
#
# Product Title: Samsung Galaxy A06 4GB/128GB
# Product URL: https://hoanghamobile.com//dien-thoai/samsung-galaxy-a06-4gb-128gb
#
# Product Title: iPhone 16 Plus (256GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-plus-256gb
#
# Product Title: iPhone 16 Pro (512GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-pro-512gb
#
# Product Title: iPhone 16 Plus (512GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-plus-512gb
#
# Product Title: iPhone 16 Pro Max (1TB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-pro-max-1tb
#
# Product Title: iPhone 16 Pro (1TB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com//dien-thoai/iphone-16-pro-1tb

# %%
import requests
from bs4 import BeautifulSoup
import time

def spider(max_pages):
    page = 1
    while page <= max_pages:
        url = 'https://hoanghamobile.com/dien-thoai-di-dong?p=' + str(page)
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        print("Products List:")
        print("=================================================")

        # Lặp qua từng sản phẩm
        for pinfo in soup.find_all('div', class_='v5-item'):
            # Lấy link sản phẩm
            link_tag = pinfo.find('h3').find('a')
            href = 'https://hoanghamobile.com' + link_tag.get('href')
            title = link_tag.get('title')

            # Lấy giá hiện tại và giá gốc của sản phẩm
            price_tag = pinfo.find('div', class_='price')
            current_price = price_tag.find('strong').text.strip() if price_tag.find('strong') else 'N/A'
            original_price = price_tag.find('strike').text.strip() if price_tag.find('strike') else 'N/A'

            # In thông tin sản phẩm
            print(f"Product Title: {title}")
            print(f"Product URL: {href}")
            print("Current Price:", current_price)
            print("Original Price:", original_price)
            print("-" * 30)

        # Thêm độ trễ giữa các request để tránh bị chặn
        time.sleep(2)  # Đợi 2 giây giữa các request
        page += 1

# Chạy hàm để kiểm tra
spider(1)  # Thay đổi số trang tùy ý nếu bạn muốn lấy thêm sản phẩm
# Out:
# Products List:
# =================================================
# Product Title: Samsung Galaxy Z Fold6 12GB/256GB
# Product URL: https://hoanghamobile.com/dien-thoai/samsung-galaxy-z-fold6
# Current Price: 41,990,000 ₫
# Original Price: 43,990,000 ₫
# ------------------------------
# Product Title: Samsung Galaxy Z Fold6 12GB/512GB
# Product URL: https://hoanghamobile.com/dien-thoai/samsung-galaxy-z-fold6-12gb-512gb
# Current Price: 45,990,000 ₫
# Original Price: 47,990,000 ₫
# ------------------------------
# Product Title: Samsung Galaxy Z Fold6 12GB/1TB
# Product URL: https://hoanghamobile.com/dien-thoai/samsung-galaxy-z-fold6-12gb-1tb
# Current Price: 52,990,000 ₫
# Original Price: 54,990,000 ₫
# ------------------------------
# Product Title: Samsung Galaxy Z Flip6 12GB/256GB
# Product URL: https://hoanghamobile.com/dien-thoai/samsung-galaxy-z-flip6
# Current Price: 26,990,000 ₫
# Original Price: 28,990,000 ₫
# ------------------------------
# Product Title: Samsung Galaxy Z Flip6 12GB/512GB
# Product URL: https://hoanghamobile.com/dien-thoai/samsung-galaxy-z-flip6-12gb-512gb
# Current Price: 30,990,000 ₫
# Original Price: 32,990,000 ₫
# ------------------------------
# Product Title: iPhone 16 Pro Max - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-pro-max
# Current Price: 34,490,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16
# Current Price: 22,190,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 Pro - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-pro
# Current Price: 28,990,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 Plus - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-plus
# Current Price: 25,990,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 Pro Max (512GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-pro-max-512gb
# Current Price: 40,990,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 (256GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-256gb
# Current Price: 25,390,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 Pro (256GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-pro-256gb
# Current Price: 31,990,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: Samsung Galaxy A06 4GB/128GB
# Product URL: https://hoanghamobile.com/dien-thoai/samsung-galaxy-a06-4gb-128gb
# Current Price: 3,490,000 ₫
# Original Price: 3,490,000 ₫
# ------------------------------
# Product Title: iPhone 16 Plus (256GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-plus-256gb
# Current Price: 28,990,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 Pro (512GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-pro-512gb
# Current Price: 37,990,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 Plus (512GB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-plus-512gb
# Current Price: 34,990,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 Pro Max (1TB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-pro-max-1tb
# Current Price: 46,990,000 ₫
# Original Price: N/A
# ------------------------------
# Product Title: iPhone 16 Pro (1TB) - Chính hãng VN/A
# Product URL: https://hoanghamobile.com/dien-thoai/iphone-16-pro-1tb
# Current Price: 43,990,000 ₫
# Original Price: N/A
# ------------------------------

# %% [markdown]
# ## Testing:

# %%
import requests

# URL to send the request
url = "https://hoanghamobile.com/Ajax/fullspecs2/5568"

# Headers to include in the request
headers = {
    "accept": "/",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "en-US,en;q=0.9",
    "referer": "https://hoanghamobile.com/dien-thoai/realme-note-60-4-64gb",
    "sec-ch-ua": '"Chromium";v="130", "Google Chrome";v="130", "Not?A_Brand";v="99"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
    "x-kl-kis-ajax-request": "Ajax_Request",
    "x-requested-with": "XMLHttpRequest"
}

# Sending the GET request
response = requests.get(url, headers=headers)

# Check the response status
if response.status_code == 200:
    # Print the response content
    print("Response content:")
    print(response.text)
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# Response content:
#
#
#
# <div class=" box-technical-specifications">
#     <div class="item-site-banner">
#         <div class="site-banner-content">
#             <i class="icon-SettingSolidOff"></i>
#             <div class="description">
#                 <span>
#                     THÔNG SỐ KỸ THUẬT
#                 </span>
#             </div>
#         </div>
#     </div>
#     <div class="text-align-start d-block box-specs-content">
#
#             <div class="specs-item">
#                 <strong class="title">M&#224;n h&#236;nh</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>C&#244;ng nghệ m&#224;n h&#236;nh</strong>
#                             <span>IPS LCD</span>
#                         </li>
#                         <li>
#                             <strong>Tần số qu&#233;t (Hz)</strong>
#                             <span>90Hz</span>
#                         </li>
#                         <li>
#                             <strong>Độ ph&#226;n giải</strong>
#                             <span>1600 x 720</span>
#                         </li>
#                         <li>
#                             <strong>K&#237;ch thước m&#224;n h&#236;nh</strong>
#                             <span>6.75"</span>
#                         </li>
#                         <li>
#                             <strong>Độ s&#225;ng m&#224;n h&#236;nh</strong>
#                             <span>560nits</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title">Camera sau</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>Quay phim</strong>
#                             <span>1080p @ 30fps, 720p @ 30fps, 480p @ 30fps</span>
#                         </li>
#                         <li>
#                             <strong>T&#237;nh năng</strong>
#                             <span>Hình ảnh, Video, Chụp đêm, 32MP, Toàn cảnh, Chân dung, Chụp ảnh chân dung thời gian, Chuyển động chậm, Quét mã QR, Ống kính Googles.</span>
#                         </li>
#                         <li>
#                             <strong>Đ&#232;n Flash</strong>
#                             <span>Có</span>
#                         </li>
#                         <li>
#                             <strong>Độ ph&#226;n giải camera</strong>
#                             <span>32MP (f/1.8)</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title">Camera trước</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>Độ ph&#226;n giải camera</strong>
#                             <span>5MP</span>
#                         </li>
#                         <li>
#                             <strong>T&#237;nh năng</strong>
#                             <span>Chụp hình, Quay video, Chân dung, Làm đẹp, Chụp bắt sáng</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title">Hệ điều h&#224;nh &amp; CPU</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>Hệ điều h&#224;nh</strong>
#                             <span>Realme UI<br />Android 14</span>
#                         </li>
#                         <li>
#                             <strong>Vi xử l&#253; đồ họa (GPU)</strong>
#                             <span>ARM Mali-G57</span>
#                         </li>
#                         <li>
#                             <strong>Vi xử l&#253;</strong>
#                             <span>Unisoc T612</span>
#                         </li>
#                         <li>
#                             <strong>Tốc độ CPU</strong>
#                             <span>Octa-core (2x1.8 GHz Cortex-A75 & 6x1.8 GHz Cortex-A55)</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title"> Bộ nhớ &amp; Lưu trữ</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>RAM</strong>
#                             <span>4GB</span>
#                         </li>
#                         <li>
#                             <strong>Bộ nhớ trong</strong>
#                             <span>64GB</span>
#                         </li>
#                         <li>
#                             <strong>Thẻ nhớ ngo&#224;i</strong>
#                             <span>Hỗ trợ thẻ nhớ tối đa 2T</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title">Kết nối</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>Số khe SIM</strong>
#                             <span>2 nano SIM + 1 khe thẻ nhớ</span>
#                         </li>
#                         <li>
#                             <strong>Wi-Fi</strong>
#                             <span>2.4GHz, 5GHz</span>
#                         </li>
#                         <li>
#                             <strong>Bluetooth</strong>
#                             <span>V5.0</span>
#                         </li>
#                         <li>
#                             <strong>Cổng kết nối/sạc</strong>
#                             <span>Type-C</span>
#                         </li>
#                         <li>
#                             <strong>Jack tai nghe</strong>
#                             <span>3.5mm</span>
#                         </li>
#                         <li>
#                             <strong>Kết nối kh&#225;c</strong>
#                             <span>AGPS, mạng LAN, OTG</span>
#                         </li>
#                         <li>
#                             <strong>Cảm biến</strong>
#                             <span>Cảm biến từ<br />Cảm biến ánh sáng<br />Cảm biến Flicker<br />Cảm biến tiệm cận<br />Cảm biến gia tốc</span>
#                         </li>
#                         <li>
#                             <strong>Mạng di động</strong>
#                             <span>4G</span>
#                         </li>
#                         <li>
#                             <strong>Định vị</strong>
#                             <span>AGPS<br />GPS<br />GLONASS<br />BDS<br />Galileo</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title">Thiết kế - trọng lượng</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>Thiết kế</strong>
#                             <span>Nguyên khối</span>
#                         </li>
#                         <li>
#                             <strong>Chất liệu</strong>
#                             <span>Nhựa</span>
#                         </li>
#                         <li>
#                             <strong>K&#237;ch thước</strong>
#                             <span>167.26mm x 76.67mm x 7.84mm</span>
#                         </li>
#                         <li>
#                             <strong>Trọng lượng</strong>
#                             <span>187g</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title">Pin &amp; Sạc</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>Dung lượng pin sản phẩm</strong>
#                             <span>5000mAh</span>
#                         </li>
#                         <li>
#                             <strong>Loại pin</strong>
#                             <span>Li-Po</span>
#                         </li>
#                         <li>
#                             <strong>C&#244;ng nghệ pin</strong>
#                             <span>Sạc nhanh</span>
#                         </li>
#                         <li>
#                             <strong>Hỗ trợ sạc tối đa</strong>
#                             <span>10W</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title">Tiện &#237;ch</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>Bảo mật sinh trắc học	</strong>
#                             <span>Vân tay cạnh viền, Khuôn mặt</span>
#                         </li>
#                         <li>
#                             <strong>T&#237;nh năng đặc biệt</strong>
#                             <span>Cảm biến cảm ứng từ, Cảm biến ánh sáng, Cảm biến tiệm cận, Con quay hồi chuyển, Cảm biến gia tốc, Hỗ trợ đếm bước chân</span>
#                         </li>
#                         <li>
#                             <strong>Kh&#225;ng nước, kh&#225;ng bụi</strong>
#                             <span>IP64</span>
#                         </li>
#                 </ul>
#             </div>
#             <div class="specs-item">
#                 <strong class="title">Th&#244;ng tin chung</strong>
#                 <ul class="specs-content">
#                         <li>
#                             <strong>Thời điểm ra mắt</strong>
#                             <span>09/2024</span>
#                         </li>
#                         <li>
#                             <strong>Sản phẩm bao gồm</strong>
#                             <span>Cáp Type C, Củ sạc nhanh rời đầu Type A, Cây lấy sim, Hộp, Sách hướng dẫn, Ốp lưng</span>
#                         </li>
#                 </ul>
#             </div>
#
#     </div>
# </div>

# %%
import requests
from bs4 import BeautifulSoup

def get_single_item_metadata(item_url):
    # Gửi yêu cầu tới trang sản phẩm
    headers = {
        "accept": "/",
        "accept-encoding": "gzip, deflate, br, zstd",
        "accept-language": "en-US,en;q=0.9",
        "referer": item_url,
        "sec-ch-ua": '"Chromium";v="130", "Google Chrome";v="130", "Not?A_Brand";v="99"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
        "x-kl-kis-ajax-request": "Ajax_Request",
        "x-requested-with": "XMLHttpRequest"
    }

    response = requests.get(item_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Tìm URL của trang cấu hình chi tiết
    ajax_link_tag = soup.find('a', class_='ajax-modal-show')
    if not ajax_link_tag:
        print("Không tìm thấy liên kết cấu hình chi tiết.")
        return

    # Tạo URL đầy đủ cho yêu cầu AJAX
    ajax_url = "https://hoanghamobile.com" + ajax_link_tag['href']
    # print("URL cấu hình chi tiết:", ajax_url)

    # Gửi yêu cầu tới URL cấu hình chi tiết với headers
    ajax_response = requests.get(ajax_url, headers=headers)
    ajax_soup = BeautifulSoup(ajax_response.text, 'html.parser')

    # Tạo dictionary để lưu trữ cấu hình chi tiết
    specs_data = {}

    # Duyệt qua từng mục specs-item trong trang cấu hình chi tiết
    for specs_item in ajax_soup.find_all('div', class_='specs-item'):
        category_title = specs_item.find('strong', class_='title').get_text(strip=True)
        specs_data[category_title] = {}

        for li in specs_item.find('ul', class_='specs-content').find_all('li'):
            attribute_name = li.find('strong').get_text(strip=True)
            attribute_value = li.find('span').get_text(separator=' ', strip=True)
            specs_data[category_title][attribute_name] = attribute_value

    # In cấu hình đầy đủ
    for category, attributes in specs_data.items():
        print(f"\n{category}:")
        for attr_name, attr_value in attributes.items():
            print(f"  {attr_name}: {attr_value}")

    return specs_data

# Ví dụ sử dụng hàm với URL của một sản phẩm
get_single_item_metadata('https://hoanghamobile.com/dien-thoai/samsung-galaxy-z-fold6')
# Out:
# Màn hình:
#   Công nghệ màn hình: Dynamic AMOLED 2X
#   Kích thước màn hình: MH chính: 7.6" MH phụ: 6.3"
#   Độ sáng màn hình: 2600nits
#   Tần số quét (Hz): 1-120Hz
#   Độ phân giải: MH chính: 2160 x 1856 MH phụ: 2376 x 968
#
# Camera sau:
#   Quay phim: UHD 8K (7680 x 4320)@30fps
#   Tính năng: AI Camera với công nghệ ProVisual Engine (AI Zoom, Chụp chân dung AI) Tính năng chụp đêm Nightography Zoom quang học 3x Zoom kỹ thuật số 30x
#   Đèn Flash: Có
#   Độ phân giải camera: 50 MP (f/1.8) + 12 MP (f/2.2) + 10 MP (f/2.4)
#
# Camera trước:
#   Độ phân giải camera: Camera trước ở màn hình phụ: 10 MP Camera ẩn dưới màn hình: 4 MP
#   Tính năng: Xóa phông Các tính năng chụp hình thông minh khác
#
# Hệ điều hành & CPU:
#   Hệ điều hành: Android 14
#   Vi xử lý đồ họa (GPU): Adreno 750
#   Vi xử lý: Snapdragon 8 Gen 3
#   Tốc độ CPU: 8-core (1x3.39GHz Cortex-X4 & 3x3.1GHz Cortex-A720 & 2x2.9GHz Cortex-A720 & 2x2.2GHz Cortex-A520)
#
# Bộ nhớ & Lưu trữ:
#   RAM: 12GB
#   Bộ nhớ còn lại (khả dụng): 216.1GB
#   Bộ nhớ trong: 256GB
#   Thẻ nhớ ngoài: Không hỗ trợ thẻ nhớ
#
# Kết nối:
#   Số khe SIM: Dual Nano-sim/ hoặc 01 Nano-sim + 01 E-sim
#   Bluetooth: V5.3
#   Cổng kết nối/sạc: Type C
#   Jack tai nghe: Không
#   Kết nối khác: Samsung Dex, hỗ trợ NFC, OTG, Smart Switch
#   Wi-Fi: 802.11a/b/g/n/ac/ax
#   Mạng di động: 5G
#   Cảm biến: Cảm biến gia tốc Cảm biến tiệm cận Cảm biến ánh sáng La bàn Cảm biến áp kế Cảm biến trọng lực
#   Định vị: GPS Glonass Beidou Galileo
#
# Thiết kế - trọng lượng:
#   Trọng lượng: 239g
#   Thiết kế: Nguyên khối Màn hình gập Tản Nhiệt Buồng Hơi
#   Chất liệu: Chất liệu khung viền: Armor aluminum Chất liệu mặt lưng máy: Gorilla Glass Victus 2
#   Kích thước: 153.5mm x 132.6mm x 5.6mm
#
# Pin & Sạc:
#   Công nghệ pin: Sạc không dây Sạc pin nhanh Tiết kiệm pin
#   Dung lượng pin sản phẩm: 4400mAh
#   Hỗ trợ sạc tối đa: 25W
#   Loại pin: Li-Ion
#
# Tiện ích:
#   Tính năng đặc biệt: Hỗ trợ S-Pen Chạm 2 lần sáng màn hình, Âm thanh AKG
#   Bảo mật sinh trắc học: Các tính năng Galaxy AI: Khoanh Tròn Để Tìm Kiếm với Google Trợ Lí Note Quyền Năng Hậu Kì Sáng Tạo Phiên Dịch Viên Phác Họa Thông Minh
#   Kháng nước, kháng bụi: IPX8
#
# Thông tin chung:
#   Thời điểm ra mắt: 07/2024
#   Sản phẩm bao gồm: Đầy đủ phụ kiện từ nhà sản xuất
# {'Màn hình': {'Công nghệ màn hình': 'Dynamic AMOLED 2X',
#   'Kích thước màn hình': 'MH chính: 7.6" MH phụ: 6.3"',
#   'Độ sáng màn hình': '2600nits',
#   'Tần số quét (Hz)': '1-120Hz',
#   'Độ phân giải': 'MH chính: 2160 x 1856 MH phụ: 2376 x 968'},
#  'Camera sau': {'Quay phim': 'UHD 8K (7680 x 4320)@30fps',
#   'Tính năng': 'AI Camera với công nghệ ProVisual Engine (AI Zoom, Chụp chân dung AI) Tính năng chụp đêm Nightography Zoom quang học 3x Zoom kỹ thuật số 30x',
#   'Đèn Flash': 'Có',
#   'Độ phân giải camera': '50 MP (f/1.8) + 12 MP (f/2.2) + 10 MP (f/2.4)'},
#  'Camera trước': {'Độ phân giải camera': 'Camera trước ở màn hình phụ: 10 MP Camera ẩn dưới màn hình: 4 MP',
#   'Tính năng': 'Xóa phông Các tính năng chụp hình thông minh khác'},
#  'Hệ điều hành & CPU': {'Hệ điều hành': 'Android 14',
#   'Vi xử lý đồ họa (GPU)': 'Adreno 750',
#   'Vi xử lý': 'Snapdragon 8 Gen 3',
#   'Tốc độ CPU': '8-core (1x3.39GHz Cortex-X4 & 3x3.1GHz Cortex-A720 & 2x2.9GHz Cortex-A720 & 2x2.2GHz Cortex-A520)'},
#  'Bộ nhớ & Lưu trữ': {'RAM': '12GB',
#   'Bộ nhớ còn lại (khả dụng)': '216.1GB',
#   'Bộ nhớ trong': '256GB',
#   'Thẻ nhớ ngoài': 'Không hỗ trợ thẻ nhớ'},
#  'Kết nối': {'Số khe SIM': 'Dual Nano-sim/ hoặc 01 Nano-sim + 01 E-sim',
#   'Bluetooth': 'V5.3',
#   'Cổng kết nối/sạc': 'Type C',
#   'Jack tai nghe': 'Không',
#   'Kết nối khác': 'Samsung Dex, hỗ trợ NFC, OTG, Smart Switch',
#   'Wi-Fi': '802.11a/b/g/n/ac/ax',
#   'Mạng di động': '5G',
#   'Cảm biến': 'Cảm biến gia tốc Cảm biến tiệm cận Cảm biến ánh sáng La bàn Cảm biến áp kế Cảm biến trọng lực',
#   'Định vị': 'GPS Glonass Beidou Galileo'},
#  'Thiết kế - trọng lượng': {'Trọng lượng': '239g',
#   'Thiết kế': 'Nguyên khối Màn hình gập Tản Nhiệt Buồng Hơi',
#   'Chất liệu': 'Chất liệu khung viền: Armor aluminum Chất liệu mặt lưng máy: Gorilla Glass Victus 2',
#   'Kích thước': '153.5mm x 132.6mm x 5.6mm'},
#  'Pin & Sạc': {'Công nghệ pin': 'Sạc không dây Sạc pin nhanh Tiết kiệm pin',
#   'Dung lượng pin sản phẩm': '4400mAh',
#   'Hỗ trợ sạc tối đa': '25W',
#   'Loại pin': 'Li-Ion'},
#  'Tiện ích': {'Tính năng đặc biệt': 'Hỗ trợ S-Pen Chạm 2 lần sáng màn hình, Âm thanh AKG',
#   'Bảo mật sinh trắc học': 'Các tính năng Galaxy AI: Khoanh Tròn Để Tìm Kiếm với Google Trợ Lí Note Quyền Năng Hậu Kì Sáng Tạo Phiên Dịch Viên Phác Họa Thông Minh',
#   'Kháng nước, kháng bụi': 'IPX8'},
#  'Thông tin chung': {'Thời điểm ra mắt': '07/2024',
#   'Sản phẩm bao gồm': 'Đầy đủ phụ kiện từ nhà sản xuất'}}

# %%
import requests
from bs4 import BeautifulSoup

def get_single_desc_item_data(item_url):
    # Gửi yêu cầu tới trang sản phẩm
    source_code = requests.get(item_url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text, 'html.parser')

    # Tìm phần tử chứa mô tả sản phẩm
    product_desc_tag = soup.find('div', class_='product-content-text box-content-text')
    if not product_desc_tag:
        print("Không tìm thấy mô tả sản phẩm.")
        return None

    # Lấy và trả về nội dung text của mô tả
    product_desc_text = product_desc_tag.get_text(separator=" ", strip=True)
    return product_desc_text

# Ví dụ sử dụng hàm với URL của một sản phẩm
desc = get_single_desc_item_data('https://hoanghamobile.com/dien-thoai/samsung-galaxy-z-fold6')
print("Mô tả sản phẩm:")
print(desc)
# Out:
# Mô tả sản phẩm:
# Samsung Galaxy Z Fold6 là dòng điện thoại thông minh thế hệ Galaxy Z Fold tiếp theo được Samsung công bố ra thị trường với nhiều tính năng và cập nhật lớn. Phiên bản này sẽ có màn hình ngoài 6.3 inch , PIN 44 00mAh , và camera trước 10 MP . Galaxy Z Fold6 còn được trang bị hệ thống làm mát lớn hơn với công nghệ chipset Snapdragon 8 Gen 3 For Galaxy cực mạnh. Kèm với đó, điện thoại sẽ có bộ nhớ lên tới 12GB RAM và được trang bị Galaxy AI. Lưu ý: Những thông tin trong bài viết mang tính chất tham khảo. Thông tin chính xác nhất sẽ được cập nhật liên tục theo dòng sự kiện ra mắt của sản phẩm. Đặc điểm nổi bật: Diện mạo mới hiện đại, thanh lịch với phần viền gấp được làm mờ đi so với các thế hệ trước. Nâng cấp lớn về camera với độ phân giải lên đến 50MP, mang lại trải nghiệm chụp ảnh chuyên nghiệp trên điện thoại. Trang bị công nghệ chipset Snapdragon 8 Gen 3 For Galaxy mạnh mẽ, đảm bảo hiệu suất hoạt động của máy. Dung lượng PIN 4400 mAh cải thiện đáng kể năng lượng so với các phiên bản trước đó. Bảng thông số kỹ thuật của Samsung Galaxy Z Fold6 Bộ xử lý Chip xử lý Snapdragon 8 Gen 3 For Galaxy Bộ nhớ RAM RAM 12GB Bộ nhớ trong 256GB, 512GB, 1TB Hỗ trợ 5G Có Màn hình Độ phân giải màn hình ngoài 968 x 2376 Pixels Độ phân giải màn hình chính 968 x 2376 pixels Công nghệ màn hình Dynamic AMOLED 2X Tần số quét 120Hz Kích thước & trọng lượng Kích thước 7.6 inch - 6.3 inch Kích thước tổng thể 153.5mm x 132.6mm x 5.6mm Trọng lượng 239g Pin và Sạc Dung lượng pin 4400mAh Công nghệ pin Tiết kiệm pin Sạc pin nhanh Sạc không dây Cổng kết nối Type-C Đánh giá chi tiết về sản phẩm Samsung Galaxy Z Fold6 Samsung một lần nữa thiết lập tiêu chuẩn mới cho các dòng điện thoại hiện nay với việc ra mắt Galaxy Z Fold6. Đây là một chiếc điện thoại gập có màn hình ngoài lớn hơn, màn hình gập bền hơn và camera chính với nhiều tính năng hơn. Đối với Samsung, đây là phiên bản Fold được đánh giá là có bước nhảy vọt khổng lồ để chiếm lĩnh thị trường. Thiết kế đa năng Thiết kế sẽ là điểm lột xác lớn nhất trên phiên bản Galaxy Z Fold 6. Sau 5 thế hệ không có quá nhiều thay đổi về thiết kế, ngoài việc khắc phục phần viền gập, thế hệ này sẽ mang đến một diện mạo hoàn toàn mới. Điểm thay đổi đầu tiên là kích thước tổng thể của Z Fold6 sẽ lớn hơn. Vì vậy, màn hình sẽ được tăng kích thước, và điện thoại sẽ có nhiều không gian bên trong để nâng cấp các linh kiện. Thêm vào đó, tỷ lệ màn hình phụ sẽ được cải thiện. Cuối cùng, giao diện màn hình ngoài hẹp cũng sẽ được sửa đổi, mang lại trải nghiệm giống như các smartphone truyền thống, giúp việc soạn thảo trở nên thuận tiện hơn. Màn hình Samsung Galaxy Z Fold 6 sắc nét với Dynamic AMOLED Màn hình Dynamic AMOLED 2X của Galaxy Z Fold6 Samsung sẽ được nâng cấp lên 7,6 inch , mang lại khả năng hiển thị rộng hơn và mãn nhãn hơn. Với kích thước mới này, độ phân giải 2160 x 1856 pixels ở màn hình chính và 968 x 2376 pixels ở màn hình phụ vẫn đảm bảo mang đến chất lượng hình ảnh sắc nét và chân thực. Không những có sự thay đổi về kích thước, tần số quét của Samsung Galaxy Z Fold6 cũng được nâng cấp đáng kể. Đây sẽ là một trong những mẫu điện thoại hiếm hoi ngoài phân khúc gaming được trang bị tần số quét 120Hz cho màn hình. Bên cạnh đó, Samsung vẫn sẽ tích hợp công nghệ làm mới thích ứng 1 - 120Hz để phù hợp với nhiều loại nội dung khác nhau. Màn hình phụ có kích thước khủng Theo một số nguồn tin cho biết Samsung Galaxy Z Fold6 có thể sẽ có một tỷ lệ khung hình mới dành cho màn hình ngoài của điện thoại. Cụ thể, kích thước màn hình ngoài được dự kiến sẽ tăng lên 6.3 inch . Nếu như điều này là thật thì sẽ là một tin cực kỳ vui cho người dùng Samsung. Bởi với các phiên bản như Samsung Z Fold 5 và Samsung Z Fold 4, hãng đã nhận lại nhiều phản hồi về màn hình ngoài của điện thoại vẫn chưa được tối ưu cho lắm, và cũng rất hẹp nên khiến các thao tác trở nên khó khăn vô cùng. Độ sáng của màn hình điện thoại Z Fold 6 cũng được bảo là sẽ đạt mức 2600 nits cao hơn rất nhiều so với 1750 nits trên Z Fold 5. Như vậy, thương hiệu Samsung có thể ...

# %%
import requests
from bs4 import BeautifulSoup

def get_single_promotion_data(item_url):
    # Gửi yêu cầu tới trang sản phẩm
    source_code = requests.get(item_url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text, 'html.parser')

    # Khởi tạo giá trị mặc định cho khuyến mãi
    promotion_text = "N/A"

    # Tìm phần tử chứa khuyến mãi qua class và id
    promotion_section = soup.find('div', class_='box-promotion-content box-content-text no-after') or \
                        soup.find('div', id='product-promotion-more')

    if promotion_section:
        # Tìm tất cả các phần tử khuyến mãi trong `promotion_section`
        promotion_items = promotion_section.find_all('div', class_='promotion-item')

        # Nếu tìm thấy khuyến mãi, lấy nội dung và nối thành chuỗi
        if promotion_items:
            promotion_text = "; ".join(
                item.find('span').get_text(separator=" ", strip=True)
                for item in promotion_items if item.find('span')
            )

    return promotion_text

# Ví dụ sử dụng hàm với URL của một sản phẩm
promotions = get_single_promotion_data('https://hoanghamobile.com/dien-thoai/samsung-galaxy-z-fold6')
print("Các chương trình khuyến mãi:")
print(promotions)
# Out:
# Các chương trình khuyến mãi:
# Trả góp tới 06 tháng không lãi suất, trả trước 0 đồng với Samsung Finance+. (Xem chi tiết); Trả góp 0% - trả trước 0Đ - Từ 1.516.000VNĐ/tháng (Xem chi tiết); Đặc quyền HS-SV: Tặng sim năm sinh (2k4-2k6) khi mua kèm điện thoại, máy tính bảng, laptop, màn hình. (Xem chi tiết); Từ ngày 01-30/11 Giảm 10% khi khách hàng mua phụ kiện kèm Phone + Tablet Apple, Samsung; Giảm 50% tối đa 700k khi mở thẻ tín dụng Vpbank trên SenID (Xem chi tiết); Giảm tới 500.000đ khi thanh toán thẻ tín dụng NCB (Xem chi tiết); Mở thẻ tín dụng VIB - Nhận Voucher 600.000đ (Xem chi tiết); Miễn phí chuyển đổi trả góp hoặc giảm đến 500.000đ khi mở thẻ TPBank EVO (Xem chi tiết); Ưu đãi trả góp 0% qua Homecredit, Shinhan Finance, Mirae asset, Homepaylater, Kredivo (Xem chi tiết); Giảm đến 150.000đ khi thanh toán qua Muadee (Xem chi tiết); Giảm thêm 100.000đ cho tất cả các sản phẩm màn hình khi mua kèm Laptop, MacBook, Máy tính bảng và Điện thoại.

# %% [markdown]
# # Save Data to Pandas Dataframe:
# ```
#   --Id
#   --Title
#   --Original Price
#   --Discount
#   --Meta_Data
#   --Description
# ```

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def get_single_item_metadata(item_url):
    # Gửi yêu cầu tới trang sản phẩm
    headers = {
        "accept": "/",
        "accept-encoding": "gzip, deflate, br, zstd",
        "accept-language": "en-US,en;q=0.9",
        "referer": item_url,
        "sec-ch-ua": '"Chromium";v="130", "Google Chrome";v="130", "Not?A_Brand";v="99"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
        "x-kl-kis-ajax-request": "Ajax_Request",
        "x-requested-with": "XMLHttpRequest"
    }

    response = requests.get(item_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Tìm URL của trang cấu hình chi tiết
    ajax_link_tag = soup.find('a', class_='ajax-modal-show')
    if not ajax_link_tag:
        return "N/A"

    # Tạo URL đầy đủ cho yêu cầu AJAX
    ajax_url = "https://hoanghamobile.com" + ajax_link_tag['href']
    ajax_response = requests.get(ajax_url, headers=headers)
    ajax_soup = BeautifulSoup(ajax_response.text, 'html.parser')

    # Tạo dictionary để lưu trữ cấu hình chi tiết
    specs_data = {}
    for specs_item in ajax_soup.find_all('div', class_='specs-item'):
        category_title = specs_item.find('strong', class_='title').get_text(strip=True)
        specs_data[category_title] = {}
        for li in specs_item.find('ul', class_='specs-content').find_all('li'):
            attribute_name = li.find('strong').get_text(strip=True)
            attribute_value = li.find('span').get_text(separator=' ', strip=True)
            specs_data[category_title][attribute_name] = attribute_value

    return specs_data

def get_single_desc_item_data(item_url):
    response = requests.get(item_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    product_desc_tag = soup.find('div', class_='product-content-text box-content-text')
    return product_desc_tag.get_text(separator=" ", strip=True) if product_desc_tag else "N/A"

def get_single_promotion_data(item_url):
    response = requests.get(item_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    promotion_section = soup.find('div', class_='box-promotion-content box-content-text no-after') or \
                        soup.find('div', id='product-promotion-more')
    if promotion_section:
        promotion_items = promotion_section.find_all('div', class_='promotion-item')
        return "; ".join(
            item.find('span').get_text(separator=" ", strip=True)
            for item in promotion_items if item.find('span')
        )
    return "N/A"

def clean_price(price_str):
    """Chuyển đổi chuỗi giá thành số nguyên."""
    return int(price_str.replace(',', '').replace('₫', '').strip()) if price_str else 0

def spider(max_pages):
    product_data = []  # List to store all product data
    page = 1
    id_counter = 1

    while page <= max_pages:
        url = 'https://hoanghamobile.com/dien-thoai-di-dong?p=' + str(page)
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        for pinfo in soup.find_all('div', class_='v5-item'):
            # Lấy link và tiêu đề sản phẩm
            link_tag = pinfo.find('h3').find('a')
            href = 'https://hoanghamobile.com' + link_tag.get('href')
            title = link_tag.get('title')

            # Lấy giá hiện tại và giá gốc của sản phẩm
            price_tag = pinfo.find('div', class_='price')
            current_price = price_tag.find('strong').text.strip() if price_tag.find('strong') else '0đ'
            original_price = price_tag.find('strike').text.strip() if price_tag.find('strike') else current_price

            # Chuyển đổi giá từ chuỗi sang số nguyên
            current_price_value = clean_price(current_price)
            original_price_value = clean_price(original_price)

            # Tính discount price
            discount_price_value = original_price_value - current_price_value

            # Gọi các hàm để lấy metadata, description, và promotions
            metadata = get_single_item_metadata(href)
            description = get_single_desc_item_data(href)
            promotions = get_single_promotion_data(href)

            # Thêm dữ liệu sản phẩm vào danh sách
            product_data.append({
                "id": id_counter,
                "product": title,
                "original_price": original_price_value,
                "current_price": current_price_value,
                "discount_price": discount_price_value,
                "metadata": metadata,
                "description": description,
                "promotions": promotions
            })
            id_counter += 1  # Tăng id cho sản phẩm tiếp theo

            # Đợi một chút để tránh bị chặn khi truy xuất dữ liệu nhanh
            time.sleep(1)  # Đợi 1 giây giữa các sản phẩm

        page += 1

    # Chuyển danh sách dữ liệu thành DataFrame
    df = pd.DataFrame(product_data)
    return df

# Gọi hàm và lưu kết quả vào DataFrame
product_df = spider(3)  # Chỉ lấy 3 trang để thử nghiệm
print(product_df.head())
# Out:
#    id                            product  original_price  current_price  \
# 0   1  Samsung Galaxy Z Fold6 12GB/256GB        43990000       41990000
# 1   2  Samsung Galaxy Z Fold6 12GB/512GB        47990000       45990000
# 2   3    Samsung Galaxy Z Fold6 12GB/1TB        54990000       52990000
# 3   4  Samsung Galaxy Z Flip6 12GB/256GB        28990000       26990000
# 4   5  Samsung Galaxy Z Flip6 12GB/512GB        32990000       30990000
#
#    discount_price                                           metadata  \
# 0         2000000  {'Màn hình': {'Công nghệ màn hình': 'Dynamic A...
# 1         2000000  {'Màn hình': {'Công nghệ màn hình': 'Dynamic A...
# 2         2000000  {'Màn hình': {'Công nghệ màn hình': 'Dynamic A...
# 3         2000000  {'Màn hình': {'Tần số quét (Hz)': '1-120Hz', '...
# 4         2000000  {'Màn hình': {'Tần số quét (Hz)': '1-120Hz', '...
#
#                                          description  \
# 0  Samsung Galaxy Z Fold6 là dòng điện thoại thôn...
# 1  Samsung Galaxy Z Fold6 là dòng điện thoại thôn...
# 2  Samsung Galaxy Z Fold6 là dòng điện thoại thôn...
# 3  Samsung Galaxy Z Flip6 là dòng điện thoại thế ...
# 4  Samsung Galaxy Z Flip6 là dòng điện thoại thế ...
#
#                                           promotions
# 0  Trả góp tới 06 tháng không lãi suất, trả trước...
# 1  Trả góp tới 06 tháng không lãi suất, trả trước...
# 2  Trả góp tới 06 tháng không lãi suất, trả trước...
# 3  Trả góp 0% - trả trước 0Đ - Từ 1.024.000VNĐ/th...
# 4  Trả góp 0% - trả trước 0Đ - Từ 1.024.000VNĐ/th...

# %%
product_df.head(1)
# Out:
#    id                            product  original_price  current_price  \
# 0   1  Samsung Galaxy Z Fold6 12GB/256GB        43990000       41990000
#
#    discount_price                                           metadata  \
# 0         2000000  {'Màn hình': {'Công nghệ màn hình': 'Dynamic A...
#
#                                          description  \
# 0  Samsung Galaxy Z Fold6 là dòng điện thoại thôn...
#
#                                           promotions
# 0  Trả góp tới 06 tháng không lãi suất, trả trước...

# %%
from google.colab import files

# Lưu DataFrame vào file CSV
product_df.to_csv('product_data_3_pages_hoangha.csv', index=False, encoding='utf-8-sig')

# Download tập dữ liệu
files.download('product_data_3_pages_hoangha.csv')

# %% [markdown]
# # Convert Data to Json Format:

# %%
def convert_raw_data_to_string(row):
    # Chuyển đổi một hàng của DataFrame thành chuỗi, bao gồm metadata
    return (f"Tên sản phẩm: {row['product']}, "
            f"Giá gốc: {row['original_price']}, "
            f"Tiền giảm: {row['discount_price']}, "
            f"Mô tả: {row['description']}, "
            f"Metadata: {row['metadata']}, "
            f"Chương trình giảm giá: {row['promotions']}")

def process_and_save_data_from_df(product_df, output_file):
    schema = schema_english  # Hoặc schema_vietnamese nếu bạn muốn dùng schema tiếng Việt

    processed_data = []

    for index, row in product_df.iterrows():
        # Chuyển đổi hàng DataFrame thành chuỗi
        raw_data = convert_raw_data_to_string(row)

        # Gọi hàm convert_to_json để chuyển đổi
        json_data = convert_to_json(raw_data, schema)

        if json_data:
            processed_data.append(json_data)

    # Lưu dữ liệu đã xử lý vào tệp JSON
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(processed_data, f, ensure_ascii=False, indent=4)

# Gọi hàm để lưu dữ liệu vào JSON (sử dụng 10 hàng để test)
process_and_save_data_from_df(product_df.head(10), 'product_data_3_pages_hoangha.json')

# %%
import json

# Hàm đọc và in nội dung JSON với định dạng dễ đọc
def pretty_print_json(file_path):
    # Đọc dữ liệu từ file JSON
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # In dữ liệu với định dạng pretty print
    print(json.dumps(data, ensure_ascii=False, indent=4))

# Sau khi đã lưu file product_data_3_pages_hoangha.json, bạn có thể gọi hàm để in
pretty_print_json('product_data_3_pages_hoangha.json')
# Out:
# [
#     {
#         "general information": {
#             "name": "Samsung Galaxy Z Fold6 12GB/256GB",
#             "brand": "Samsung",
#             "category": "Smartphone",
#             "original_price": 43990000.0,
#             "discount_price": 41990000.0,
#             "description": "Samsung Galaxy Z Fold6 là dòng điện thoại thông minh thế hệ Galaxy Z Fold tiếp theo được Samsung công bố ra thị trường với nhiều tính năng và cập nhật lớn. Phiên bản này sẽ có màn hình ngoài 6.3 inch, PIN 4400mAh, và camera trước 10 MP. Galaxy Z Fold6 còn được trang bị hệ thống làm mát lớn hơn với công nghệ chipset Snapdragon 8 Gen 3 For Galaxy cực mạnh.",
#             "design": "Thiết kế đa năng, màn hình gập",
#             "promotion": "Giảm giá 2,000,000 VNĐ"
#         },
#         "technical specifications": {
#             "display": [
#                 "Màn hình chính: 7.6 inch Dynamic AMOLED 2X, độ phân giải 2160 x 1856 pixels, tần số quét 120Hz",
#                 "Màn hình phụ: 6.3 inch, độ phân giải 968 x 2376 pixels"
#             ],
#             "memory and storage": [
#                 "RAM: 12GB",
#                 "Bộ nhớ trong: 256GB, 512GB, 1TB"
#             ],
#             "camera": "Camera chính: 50MP + 12MP + 10MP, Camera trước: 10MP + 4MP",
#             "battery": "4400mAh, hỗ trợ sạc nhanh",
#             "operating system": "Android 14",
#             "chip": "Snapdragon 8 Gen 3 For Galaxy",
#             "connectivity": [
#                 "5G",
#                 "Wi-Fi 802.11a/b/g/n/ac/ax",
#                 "Bluetooth V5.3",
#                 "Type-C"
#             ],
#             "audio": "Âm thanh AKG",
#             "charging and expansion": [
#                 "Sạc nhanh không dây",
#                 "Sạc nhanh có dây 25W"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "Hỗ trợ S-Pen",
#                 "Chống nước IPX8"
#             ],
#             "accessories": [
#                 "Sạc nhanh",
#                 "Cáp Type-C"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "Samsung Galaxy Z Fold6 12GB/512GB",
#             "brand": "Samsung",
#             "category": "Smartphone",
#             "original_price": 47990000.0,
#             "discount_price": 2000000.0,
#             "description": "Samsung Galaxy Z Fold6 là dòng điện thoại thông minh thế hệ Galaxy Z Fold tiếp theo được Samsung công bố ra thị trường với nhiều tính năng và cập nhật lớn. Phiên bản này sẽ có màn hình ngoài 6.3 inch, PIN 4400mAh, và camera trước 10 MP. Galaxy Z Fold6 còn được trang bị hệ thống làm mát lớn hơn với công nghệ chipset Snapdragon 8 Gen 3 For Galaxy cực mạnh. Kèm với đó, điện thoại sẽ có bộ nhớ lên tới 12GB RAM và được trang bị Galaxy AI.",
#             "design": "Thiết kế đa năng, mỏng nhẹ, với khung viền Armor aluminum và mặt lưng Gorilla Glass Victus 2.",
#             "promotion": "Giảm giá 10% khi khách hàng mua phụ kiện kèm Phone + Tablet Apple, Samsung."
#         },
#         "technical specifications": {
#             "display": [
#                 "Màn hình chính: 7.6 inch Dynamic AMOLED 2X, độ phân giải 2160 x 1856 pixels, tần số quét 120Hz",
#                 "Màn hình phụ: 6.3 inch, độ phân giải 968 x 2376 pixels"
#             ],
#             "memory and storage": [
#                 "RAM: 12GB",
#                 "Bộ nhớ trong: 512GB, có tùy chọn 256GB và 1TB"
#             ],
#             "camera": "Camera chính: 50MP + 12MP + 10MP, Camera trước: 10MP + 4MP",
#             "battery": "4400mAh, hỗ trợ sạc nhanh 25W, sạc không dây",
#             "operating system": "Android 14",
#             "chip": "Snapdragon 8 Gen 3",
#             "connectivity": [
#                 "5G",
#                 "Wi-Fi 802.11a/b/g/n/ac/ax",
#                 "Bluetooth 5.3",
#                 "NFC"
#             ],
#             "audio": "Âm thanh AKG",
#             "charging and expansion": [
#                 "Cổng sạc Type-C",
#                 "Không có jack tai nghe"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "Hỗ trợ S-Pen",
#                 "Chống nước IPX8"
#             ],
#             "accessories": [
#                 "Cáp Type C",
#                 "Cây lấy sim",
#                 "Hộp",
#                 "Sách hướng dẫn"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "Samsung Galaxy Z Fold6 12GB/1TB",
#             "brand": "Samsung",
#             "category": "Smartphone",
#             "original_price": 54990000.0,
#             "discount_price": 52990000.0,
#             "description": "Samsung Galaxy Z Fold6 là dòng điện thoại thông minh thế hệ Galaxy Z Fold tiếp theo được Samsung công bố ra thị trường với nhiều tính năng và cập nhật lớn. Phiên bản này sẽ có màn hình ngoài 6.3 inch, PIN 4400mAh, và camera trước 10 MP. Galaxy Z Fold6 còn được trang bị hệ thống làm mát lớn hơn với công nghệ chipset Snapdragon 8 Gen 3 For Galaxy cực mạnh. Kèm với đó, điện thoại sẽ có bộ nhớ lên tới 12GB RAM và được trang bị Galaxy AI.",
#             "design": "Thiết kế gập, mỏng nhẹ, khung viền nhôm Armor, mặt lưng Gorilla Glass Victus 2.",
#             "promotion": "Giảm giá 10% khi mua phụ kiện kèm Phone + Tablet Apple, Samsung."
#         },
#         "technical specifications": {
#             "display": [
#                 "Màn hình chính: 7.6 inch Dynamic AMOLED 2X, độ phân giải 2160 x 1856 pixels, tần số quét 120Hz",
#                 "Màn hình phụ: 6.3 inch Dynamic AMOLED 2X, độ phân giải 968 x 2376 pixels"
#             ],
#             "memory and storage": [
#                 "RAM: 12GB",
#                 "Bộ nhớ trong: 256GB, 512GB, 1TB"
#             ],
#             "camera": "Camera chính: 50MP + 12MP + 10MP, Camera trước: 10MP + 4MP",
#             "battery": "4400mAh, hỗ trợ sạc nhanh 25W, sạc không dây",
#             "operating system": "Android 14",
#             "chip": "Snapdragon 8 Gen 3 For Galaxy",
#             "connectivity": [
#                 "5G",
#                 "Wi-Fi 802.11a/b/g/n/ac/ax",
#                 "Bluetooth 5.3",
#                 "NFC"
#             ],
#             "audio": "Âm thanh AKG",
#             "charging and expansion": [
#                 "Cổng sạc Type-C",
#                 "Không hỗ trợ thẻ nhớ ngoài"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "Hỗ trợ S-Pen",
#                 "Chống nước IPX8"
#             ],
#             "accessories": [
#                 "Cáp Type C",
#                 "Cây lấy sim",
#                 "Hộp",
#                 "Sách hướng dẫn sử dụng"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "Samsung Galaxy Z Flip6 12GB/256GB",
#             "brand": "Samsung",
#             "category": "Smartphone",
#             "original_price": 28990000.0,
#             "discount_price": 2000000.0,
#             "description": "Samsung Galaxy Z Flip6 là dòng điện thoại thế hệ Galaxy Z Flip tiếp theo được Samsung công bố ra thị trường với nhiều tính năng và cập nhật lớn. Phiên bản này sẽ có màn hình phụ 3.4 inch, pin 4000mAh và camera chính 50MP. Galaxy Z Flip6 còn được trang bị bộ vi xử lý lớn hơn với chip Snapdragon 8 Gen 3 dành cho Galaxy cực mạnh.",
#             "design": "Thiết kế nguyên khối, màn hình gập, tản nhiệt đầu tiên trên dòng Z Flip.",
#             "promotion": "Giảm giá 10% khi mua phụ kiện kèm Phone + Tablet Apple, Samsung."
#         },
#         "technical specifications": {
#             "display": [
#                 "Màn hình chính: Dynamic AMOLED 2X, Kích thước: 6.7 inch, Độ phân giải: 2640x1080 (FHD+), Tốc độ làm mới: 120Hz, Độ sáng tối đa: 2600 nit, Mặt kính: Gorilla Glass Victus 2",
#                 "Màn hình phụ: Super AMOLED, Kích thước: 3.4 inch, Độ phân giải: 720x748"
#             ],
#             "memory and storage": [
#                 "RAM: 12GB",
#                 "Bộ nhớ trong: 256GB"
#             ],
#             "camera": "Camera Sau: 50MP + 12MP, Camera Trước: 10MP",
#             "battery": "Dung lượng pin: 4000mAh, Công nghệ sạc: Sạc nhanh 25W, Sạc không dây 10W",
#             "operating system": "Android 14",
#             "chip": "Snapdragon 8 Gen 3",
#             "connectivity": [
#                 "1 Nano-sim & 1 E-sim",
#                 "Bluetooth: V5.3",
#                 "Wi-Fi: 802.11a/b/g/n/ac/ax",
#                 "5G"
#             ],
#             "audio": "Loa stereo, không có jack tai nghe",
#             "charging and expansion": [
#                 "Cổng kết nối: Type C",
#                 "Hỗ trợ NFC, OTG, Smart Switch"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "FlexCam với Auto Zoom AI",
#                 "Bảo mật sinh trắc học: Mở khóa vân tay cạnh viền"
#             ],
#             "accessories": [
#                 "Cáp truyền dữ liệu",
#                 "Que lấy sim"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "Samsung Galaxy Z Flip6 12GB/512GB",
#             "brand": "Samsung",
#             "category": "Smartphone",
#             "original_price": 32990000.0,
#             "discount_price": 30990000.0,
#             "description": "Samsung Galaxy Z Flip6 là dòng điện thoại thế hệ Galaxy Z Flip tiếp theo được Samsung công bố ra thị trường với nhiều tính năng và cập nhật lớn. Phiên bản này sẽ có màn hình phụ 3.4 inch, pin 4000mAh và camera chính 50MP. Galaxy Z Flip6 còn được trang bị bộ vi xử lý lớn hơn với chip Snapdragon 8 Gen 3 dành cho Galaxy cực mạnh.",
#             "design": "Thiết kế của Galaxy Z Flip6 không có nhiều thay đổi so với Galaxy Z Flip5, nhưng có phần vuông vức, góc cạnh và sắc sảo hơn.",
#             "promotion": "Giảm giá 10% khi khách hàng mua phụ kiện kèm Phone + Tablet Apple, Samsung; Giảm 50% tối đa 700k khi mở thẻ tín dụng Vpbank trên SenID."
#         },
#         "technical specifications": {
#             "display": [
#                 "Màn hình chính: Dynamic AMOLED 2X, Kích thước: 6.7 inch, Độ phân giải: 2640x1080 (FHD+), Tốc độ làm mới: 120Hz, Độ sáng tối đa: 2600 nit, Mặt kính: Gorilla Glass Victus 2",
#                 "Màn hình phụ: Super AMOLED, Kích thước: 3.4 inch, Độ phân giải: 720x748"
#             ],
#             "memory and storage": [
#                 "RAM: 12GB",
#                 "Bộ nhớ trong: 512GB"
#             ],
#             "camera": "Camera Sau: 50MP + 12MP, Camera Trước: 10MP",
#             "battery": "Dung lượng pin: 4000mAh, Công nghệ sạc: Sạc nhanh 25W, Sạc không dây 10W",
#             "operating system": "Android 14 với giao diện One UI 6.1.1",
#             "chip": "Snapdragon 8 Gen 3",
#             "connectivity": [
#                 "1 Nano-sim & 1 E-sim",
#                 "Bluetooth: V5.3",
#                 "Wi-Fi: 802.11a/b/g/n/ac/ax",
#                 "5G"
#             ],
#             "audio": "Loa stereo, không có jack tai nghe",
#             "charging and expansion": [
#                 "Cổng kết nối: Type C",
#                 "Hỗ trợ NFC, OTG, Smart Switch"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "FlexCam với Auto Zoom AI",
#                 "Kháng nước, kháng bụi: IPX8"
#             ],
#             "accessories": [
#                 "Cáp truyền dữ liệu",
#                 "Que lấy sim"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "iPhone 16 Pro Max - Chính hãng VN/A",
#             "brand": "Apple",
#             "category": "Smartphone",
#             "original_price": 34490000.0,
#             "discount_price": 0.0,
#             "description": "Apple vừa ra mắt iPhone 16 Pro Max (256GB) mới và mang đến cho các tín đồ iPhone một mẫu điện thoại được cải tiến nhiều nhất trong bốn mẫu mà thương hiệu này đã giới thiệu tại sự kiện Glowtime. iPhone 16 Pro Max có thay đổi một chút về kích thước với màn hình 6.9 inch lớn hơn, viền mỏng hơn và lớp hoàn thiện bằng titan. Sự bứt phá các nâng cấp vượt trội về camera cũng là điểm nhấn với Apple Intelligence (AI) bao gồm nút Điều khiển Camera - Camera Control.",
#             "design": "Màn hình 6.9 inch lớn hơn với viền cực mỏng mang lại trải nghiệm xem đắm chìm, kết hợp với lớp hoàn thiện titan mới tạo nên vẻ ngoài cao cấp và bền.",
#             "promotion": "Giảm thêm 500K - 2TR qua cổng thanh toán; Miễn phí chuyển đổi trả góp qua 26 ngân hàng; Giảm ngay 2.000.000đ khi thanh toán thẻ tín dụng Shinhan Finance Mastercard THE FIRST (Gold); Giảm 1.000.000đ, cashback 200.000đ khi mở và sử dụng thẻ tín dụng VPBank trên SenID (Xem chi tiết); Từ ngày 01-30/11 Giảm 10% khi khách hàng mua phụ kiện kèm Phone + Tablet Apple, Samsung; Giảm đến 1.500.000đ khi thanh toán thẻ tín dụng VIB (Xem chi tiết); Giảm ngay 1.000.000đ khi thanh toán thẻ tín dụng Vietbank; Giảm tới 500.000đ khi thanh toán thẻ tín dụng NCB (Xem chi tiết); Mở thẻ tín dụng VIB - Nhận Voucher 600.000đ (Xem chi tiết); Miễn phí chuyển đổi trả góp hoặc giảm đến 500.000đ khi mở thẻ TPBank EVO (Xem chi tiết); Ưu đãi trả góp 0% qua thẻ tín dụng; Ưu đãi trả góp 0% qua Homecredit, Shinhan Finance, Mirae asset, Homepaylater, Kredivo (Xem chi tiết); Giảm thêm tới 1.000.000đ hoặc Trả góp 0% khi thanh toán qua Kredivo (Xem chi tiết); Đặc quyền iPhone 16 series: Dành tặng 10.000 Esim nhà mạng Vnsky (Xem chi tiết)"
#         },
#         "technical specifications": {
#             "display": [
#                 "Kích thước màn hình: 6.9 inch",
#                 "Công nghệ màn hình: Super Retina XDR OLED",
#                 "Độ phân giải màn hình: 2868 x 1320 pixels",
#                 "Tính năng màn hình: Dynamic Island, HDR, True Tone, Dải màu rộng (P3), Haptic Touch, Tỷ lệ tương phản 2.000.000:1, Độ sáng tối đa 1000 nit, 460 ppi"
#             ],
#             "memory and storage": [
#                 "Bộ nhớ trong: 256 GB",
#                 "RAM: 8 GB"
#             ],
#             "camera": "Camera chính: 48MP, f/1.78, 24mm, chống rung quang học, Camera góc siêu rộng: 48MP, 13mm, f/2.2, Camera tele: 12MP, f/1.6, zoom quang 5X",
#             "battery": "Pin Lithium-ion, Dung lượng pin: 3274 mAh",
#             "operating system": "iOS 18",
#             "chip": "Apple A18 Pro",
#             "connectivity": [
#                 "Công nghệ NFC",
#                 "SIM kép (nano-SIM và e-SIM)",
#                 "Hỗ trợ 2 e-SIM",
#                 "Mạng 5G",
#                 "Wifi 7 (802.11be) với 2x2 MIMO",
#                 "Bluetooth 5.3",
#                 "GPS, GLONASS, Galileo, QZSS và BeiDou"
#             ],
#             "audio": "Hỗ trợ âm thanh AAC, APAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, và Dolby Atmos",
#             "charging and expansion": [
#                 "Sạc không dây MagSafe lên đến 25W với bộ tiếp hợp 30W",
#                 "Sạc không dây Qi2 lên đến 15W",
#                 "Sạc không dây Qi lên đến 7,5W",
#                 "Cổng sạc USB Type-C"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "Face ID",
#                 "FaceTime",
#                 "Apple Pay",
#                 "SOS Khẩn Cấp",
#                 "Phát Hiện Va Chạm"
#             ],
#             "accessories": [
#                 "Cáp sạc USB-C (1 m)",
#                 "Tài liệu"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "iPhone 16 - Chính hãng VN/A",
#             "brand": "Apple",
#             "category": "Smartphone",
#             "original_price": 22190000.0,
#             "discount_price": 22190000.0,
#             "description": "iPhone 16 đã chính thức được ra mắt trong sự kiện “Its Glow Time” tại nhà hát Steve Jobs, California (Mỹ) vào lúc 10h sáng 9/9, tức 0h ngày 10/9 theo giờ Việt Nam. Đây là phiên bản tiêu chuẩn trong bộ tứ flagship thuộc dòng iPhone 16 Series cao cấp nhất năm 2024.",
#             "design": "Thiết kế hiện đại với 5 màu sắc, kích thước gọn nhẹ thoải mái cầm nắm.",
#             "promotion": "Giảm 500K - 2TR khi thanh toán + tặng củ sạc; Miễn phí chuyển đổi trả góp qua 26 ngân hàng; Giảm ngay 2.000.000đ khi thanh toán thẻ tín dụng Shinhan Finance Mastercard THE FIRST (Gold); Giảm 1.000.000đ, cashback 200.000đ khi mở và sử dụng thẻ tín dụng VPBank trên SenID."
#         },
#         "technical specifications": {
#             "display": [
#                 "Kích thước 6,1 inch",
#                 "Độ phân giải màn hình chính 1179 x 2556 pixel, tỉ lệ 19,5:9 (~mật độ 461 ppi)",
#                 "Công nghệ màn hình Super Retina XDR OLED, HDR10, Dolby Vision, 1000 nits (điểm ảnh), 2000 nits (HBM)",
#                 "Tần số quét 60Hz"
#             ],
#             "memory and storage": [
#                 "RAM 8GB",
#                 "Bộ nhớ trong 128GB, 256GB, 512GB"
#             ],
#             "camera": "Camera sau chính 48 MP, f/1.6, 26mm (rộng), 1/1.56\", 1.0µm, PDAF, OIS; Camera góc rộng 12 MP, f/2.2, 13mm, 120° (siêu rộng), 0.7µm, PDAF; Camera trước 12 MP, f/1.9, 23mm (rộng), 1/3.6\", PDAF.",
#             "battery": "Chưa tiết lộ dung lượng pin; Công nghệ pin có dây, PD2.0, 50% trong 30 phút (được quảng cáo); Không dây 25W (MagSafe), Không dây 15W (Qi2).",
#             "operating system": "iOS 18",
#             "chip": "Apple A18 (3nm)",
#             "connectivity": [
#                 "5G",
#                 "Wi-Fi 7 (802.11be)",
#                 "Bluetooth V5.3",
#                 "NFC"
#             ],
#             "audio": "Có",
#             "charging and expansion": [
#                 "Type-C"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "Face ID",
#                 "Tính năng Apple Intelligence giúp viết lách, tạo biểu tượng cảm xúc từ nội dung bạn muốn biểu thị."
#             ],
#             "accessories": [
#                 "Cáp sạc USB-C (1m)"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "iPhone 16 Pro - Chính hãng VN/A",
#             "brand": "Apple",
#             "category": "Smartphone",
#             "original_price": 28990000.0,
#             "discount_price": 0.0,
#             "description": "Apple vừa ra mắt iPhone 16 Pro (128GB) mới và mang đến cho các tín đồ iPhone một mẫu điện thoại được cải tiến nhiều nhất trong bốn mẫu mà thương hiệu này đã giới thiệu tại sự kiện Glowtime. iPhone 16 Pro có thay đổi một chút về kích thước với màn hình 6.3 inch lớn hơn, viền mỏng hơn và lớp hoàn thiện bằng titan. Sự bứt phá các nâng cấp vượt trội về camera cũng là điểm nhấn với Apple Intelligence (AI) bao gồm nút Điều khiển Camera - Camera Control.",
#             "design": "Màn hình 6.3 inch lớn hơn với viền cực mỏng mang lại trải nghiệm xem đắm chìm, kết hợp với lớp hoàn thiện titan mới tạo nên vẻ ngoài cao cấp và bền.",
#             "promotion": "Giảm 500K - 2TR khi thanh toán + tặng củ sạc; Miễn phí chuyển đổi trả góp qua 26 ngân hàng; Giảm ngay 2.000.000đ khi thanh toán thẻ tín dụng Shinhan Finance Mastercard THE FIRST (Gold); Giảm 1.000.000đ, cashback 200.000đ khi mở và sử dụng thẻ tín dụng VPBank trên SenID (Xem chi tiết); Từ ngày 01-30/11 Giảm 10% khi khách hàng mua phụ kiện kèm Phone + Tablet Apple, Samsung; Giảm đến 1.500.000đ khi thanh toán thẻ tín dụng VIB (Xem chi tiết); Giảm ngay 1.000.000đ khi thanh toán thẻ tín dụng Vietbank; Giảm tới 500.000đ khi thanh toán thẻ tín dụng NCB (Xem chi tiết); Mở thẻ tín dụng VIB - Nhận Voucher 600.000đ (Xem chi tiết); Miễn phí chuyển đổi trả góp hoặc giảm đến 500.000đ khi mở thẻ TPBank EVO (Xem chi tiết); Ưu đãi trả góp 0% qua thẻ tín dụng; Ưu đãi trả góp 0% qua Homecredit, Shinhan Finance, Mirae asset, Homepaylater, Kredivo (Xem chi tiết); Giảm thêm tới 1.000.000đ hoặc Trả góp 0% khi thanh toán qua Kredivo (Xem chi tiết); Đặc quyền iPhone 16 series: Dành tặng 10.000 Esim nhà mạng Vnsky (Xem chi tiết)"
#         },
#         "technical specifications": {
#             "display": [
#                 "Công nghệ màn hình: Super Retina XDR",
#                 "Độ phân giải màn hình: 2622 x 1206 pixels",
#                 "Độ sáng màn hình: 2000 nits",
#                 "Tần số quét (Hz): 10-120Hz",
#                 "Kích thước màn hình: 6.3 inch"
#             ],
#             "memory and storage": [
#                 "Bộ nhớ trong: 128GB",
#                 "RAM: 8GB"
#             ],
#             "camera": "Camera chính: 48MP, f/1.78, 24mm, chống rung quang học, Focus Pixels 100%; Camera góc siêu rộng: 48MP, 13mm, f/2.2; Camera tele: 12MP, 52mm, f/1.6; Quay video 4K Dolby Vision ở tốc độ 24fps.",
#             "battery": "Loại pin: Li-Ion, Dung lượng pin: 3274 mAh",
#             "operating system": "iOS 18",
#             "chip": "Apple A18 Pro",
#             "connectivity": [
#                 "Công nghệ NFC",
#                 "SIM kép (nano-SIM và e-SIM)",
#                 "Hỗ trợ 2 e-SIM",
#                 "Hệ điều hành: iOS 18",
#                 "Hỗ trợ mạng 5G",
#                 "Wifi 7 (802.11be) với 2x2 MIMO",
#                 "Bluetooth 5.3",
#                 "GPS, GLONASS, Galileo, QZSS và BeiDou"
#             ],
#             "audio": "AAC, APAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, và Dolby Atmos",
#             "charging and expansion": [
#                 "Sạc không dây MagSafe lên đến 25W với bộ tiếp hợp 30W",
#                 "Sạc không dây Qi2 lên đến 15W",
#                 "Sạc không dây Qi lên đến 7.5W",
#                 "Cổng sạc USB Type-C"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "Face ID",
#                 "FaceTime",
#                 "Apple Pay",
#                 "SOS Khẩn Cấp",
#                 "Phát Hiện Va Chạm"
#             ],
#             "accessories": [
#                 "Cáp Sạc USB-C (1 m)",
#                 "Tài liệu"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "iPhone 16 Plus",
#             "brand": "Apple",
#             "category": "Smartphone",
#             "original_price": 25990000.0,
#             "discount_price": 0.0,
#             "description": "iPhone 16 Plus đã chính thức được ra mắt trong sự kiện “Its Glow Time” tại nhà hát Steve Jobs, California (Mỹ) vào lúc 10h sáng 9/9, tức 0h ngày 10/9 theo giờ Việt Nam. Đây là phiên bản tiêu chuẩn trong bộ tứ flagship thuộc dòng iPhone 16 Series cao cấp nhất năm 2024.",
#             "design": "Thiết kế cao cấp với cụm camera đặt dọc.",
#             "promotion": "Giảm thêm 500K - 2TR qua cổng thanh toán; Miễn phí chuyển đổi trả góp qua 26 ngân hàng; Giảm ngay 2.000.000đ khi thanh toán thẻ tín dụng Shinhan Finance Mastercard THE FIRST (Gold); Giảm 1.000.000đ, cashback 200.000đ khi mở và sử dụng thẻ tín dụng VPBank trên SenID."
#         },
#         "technical specifications": {
#             "display": [
#                 "Kích thước màn hình: 6.7 inch",
#                 "Độ phân giải màn hình: 2796 x 1290 pixel (~461 ppi)",
#                 "Công nghệ màn hình: Super Retina XDR OLED",
#                 "Tần số quét: 60Hz",
#                 "Độ sáng màn hình: 2000 nits"
#             ],
#             "memory and storage": [
#                 "Bộ nhớ trong: 128GB, 256GB, 512GB",
#                 "RAM: 8GB"
#             ],
#             "camera": "Camera chính 48 MP, f/1.6, 26mm, Camera góc rộng 12 MP, f/2.2, 13mm, Camera trước 12 MP, f/1.9, 23mm.",
#             "battery": "Công nghệ pin: Li-Ion, hỗ trợ sạc nhanh 30W.",
#             "operating system": "iOS 18",
#             "chip": "Apple A18 (3nm)",
#             "connectivity": [
#                 "5G",
#                 "Wi-Fi 7 (802.11be)",
#                 "Bluetooth V5.3",
#                 "NFC"
#             ],
#             "audio": "Có loa stereo, hỗ trợ âm thanh không gian.",
#             "charging and expansion": [
#                 "Cổng kết nối: Type-C",
#                 "Sạc không dây MagSafe lên đến 25W"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "Face ID",
#                 "Chống nước, chống bụi: IP68",
#                 "Tính năng Apple Intelligence"
#             ],
#             "accessories": [
#                 "Cáp sạc USB-C (1m)",
#                 "Tài liệu hướng dẫn"
#             ]
#         }
#     },
#     {
#         "general information": {
#             "name": "iPhone 16 Pro Max (512GB)",
#             "brand": "Apple",
#             "category": "Smartphone",
#             "original_price": 40990000.0,
#             "discount_price": 0.0,
#             "description": "Apple vừa ra mắt iPhone 16 Pro Max (512GB) mới và mang đến cho các tín đồ iPhone một mẫu điện thoại được cải tiến nhiều nhất trong bốn mẫu mà thương hiệu này đã giới thiệu tại sự kiện Glowtime. iPhone 16 Pro Max có thay đổi một chút về kích thước với màn hình 6.9 inch lớn hơn, viền mỏng hơn và lớp hoàn thiện bằng titan. Sự bổ sung các nâng cấp vượt trội về camera cũng là điểm nhấn với Apple Intelligence (AI) bao gồm nút Điều khiển Camera - Camera Control.",
#             "design": "Màn hình 6.9 inch lớn hơn với viền cực mỏng mang lại trải nghiệm xem đắm chìm, kết hợp với lớp hoàn thiện titan mới tạo nên vẻ ngoài cao cấp và bền.",
#             "promotion": "Giảm ngay 2.000.000đ khi thanh toán thẻ tín dụng Shinhan Finance Mastercard THE FIRST (Gold); Giảm 1.000.000đ, cashback 200.000đ khi mở và sử dụng thẻ tín dụng VPBank trên SenID."
#         },
#         "technical specifications": {
#             "display": [
#                 "Kích thước màn hình 6.9 inch",
#                 "Công nghệ màn hình Super Retina XDR OLED",
#                 "Độ phân giải màn hình 2868 x 1320 pixels",
#                 "Tính năng màn hình Dynamic Island",
#                 "Màn hình HDR True Tone",
#                 "Độ sáng tối đa 2000 nit"
#             ],
#             "memory and storage": [
#                 "Bộ nhớ trong 512 GB",
#                 "RAM 8 GB"
#             ],
#             "camera": "Camera chính: 48MP, f/1.78, 24mm, chống rung quang học; Camera góc siêu rộng: 48MP, 13mm, f/2.2; Camera tele: 12MP, f/1.6, zoom quang 5x.",
#             "battery": "Pin Lithium-ion, dung lượng 3274 mAh.",
#             "operating system": "iOS 18",
#             "chip": "Apple A18 Pro",
#             "connectivity": [
#                 "Công nghệ NFC",
#                 "SIM kép (nano-SIM và e-SIM)",
#                 "Hỗ trợ 5G",
#                 "Wifi 7 (802.11be)",
#                 "Bluetooth 5.3",
#                 "GPS, GLONASS, Galileo, QZSS và BeiDou"
#             ],
#             "audio": "Hỗ trợ âm thanh AAC, APAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, và Dolby Atmos.",
#             "charging and expansion": [
#                 "Sạc không dây MagSafe lên đến 25W",
#                 "Sạc không dây Qi2 lên đến 15W",
#                 "Cổng sạc USB Type-C"
#             ]
#         },
#         "extra_metadata": {
#             "special feature": [
#                 "Face ID",
#                 "Camera Control",
#                 "Apple Intelligence"
#             ],
#             "accessories": [
#                 "Cáp sạc USB-C",
#                 "Tài liệu hướng dẫn"
#             ]
#         }
#     }
# ]
